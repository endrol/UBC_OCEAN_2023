# %%
from PIL import Image
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ### Check train ino and image

# %%
traininfo = pd.read_csv('data/train.csv')
print(traininfo["label"].value_counts())

traininfo.head(6)
# Out:
# HGSC    222
# EC      124
# CC       99
# LGSC     47
# MC       46
# Name: label, dtype: int64
#    image_id label  image_width  image_height  is_tma
# 0         4  HGSC        23785         20008   False
# 1        66  LGSC        48871         48195   False
# 2        91  HGSC         3388          3388    True
# 3       281  LGSC        42309         15545   False
# 4       286    EC        37204         30020   False
# 5       431  HGSC        39991         40943   False

# %%
traininfo["label"].value_counts().plot.pie(autopct="%1.1f%%", ylabel="label", figsize=(3,3))
# Out:
# <AxesSubplot:ylabel='label'>

# %% [markdown]
# ## Show images

# %%
from PIL import Image
import numpy as np
data_dir = "./data/train_thumbnails"

# %%
hgsc_info = traininfo[traininfo["label"]=='HGSC']

img = np.array(Image.open(f"{data_dir}/{hgsc_info.iloc[0]['image_id']}_thumbnail.png"))
plt.imshow(img)

# %%
mc_info = traininfo[traininfo["label"]=='MC']

img = np.array(Image.open(f"{data_dir}/{mc_info.iloc[0]['image_id']}_thumbnail.png"))
plt.imshow(img)

# %%
lgsc_info = traininfo[traininfo["label"]=='LGSC']

img = np.array(Image.open(f"{data_dir}/{lgsc_info.iloc[0]['image_id']}_thumbnail.png"))
plt.imshow(img)

# %%
ec_info = traininfo[traininfo["label"]=='EC']

img = np.array(Image.open(f"{data_dir}/{ec_info.iloc[0]['image_id']}_thumbnail.png"))
plt.imshow(img)

# %%
cc_info = traininfo[traininfo["label"]=='CC']

img = np.array(Image.open(f"{data_dir}/{cc_info.iloc[0]['image_id']}_thumbnail.png"))
plt.imshow(img)

# %%
import timm
timm.list_models("*densenet*")
# Out:
# ['densenet121',
#  'densenet121d',
#  'densenet161',
#  'densenet169',
#  'densenet201',
#  'densenet264',
#  'densenet264d_iabn',
#  'densenetblur121d',
#  'tv_densenet121']
